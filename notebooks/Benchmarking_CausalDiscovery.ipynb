# %% [markdown]
# # Causal Discovery Benchmarking

# %%
from importlib.util import find_spec
if find_spec("causai") is None:
    import sys
    sys.path.append('..')

import pandas as pd

import causai
from causai.plotting import plot_graph
from causai.datasets import load_datasets
from causai.metrics import precision_recall

# from causai.discovery.causal_discovery import GES
from causai.discovery.independence import Glasso
from causai.util import remove_indirect_links

# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
data, graph = load_datasets('sanchs')

# %%
data.head()
# Out:
#    praf  pmek   plcg   PIP2   PIP3  p44/42  pakts473    PKA    PKC   P38  pjnk
# 0  26.4  13.2   8.82  18.30  58.80    6.61      17.0  414.0  17.00  44.9  40.0
# 1  35.9  16.5  12.30  16.80   8.13   18.60      32.5  352.0   3.37  16.5  61.5
# 2  59.4  44.1  14.60  10.20  13.00   14.90      32.5  403.0  11.40  31.9  19.5
# 3  73.0  82.8  23.10  13.50   1.29    5.83      11.8  528.0  13.70  28.6  23.1
# 4  33.7  19.8   5.19   9.73  24.80   21.10      46.1  305.0   4.66  25.7  81.3

# %%
plot_graph(graph)

# %% [markdown]
# ## Independence

# %%
glasso = Glasso()
graph_skelethon= glasso.predict(data)
plot_graph(graph_skelethon)

# %%
new_skelethon = remove_indirect_links(graph_skelethon)
plot_graph(new_skelethon)

# %% [markdown]
# ## Causal Discovery Graph

# %%
model = GES()
output_graph=model.predict(data, new_skelethon)
plot_graph(output_graph)

# %%
precision_recall(graph, output_graph)

# %%
# Out:
# 3.38MB [00:03, 994kB/s]
# 96.0kB [00:00, 123kB/s]
